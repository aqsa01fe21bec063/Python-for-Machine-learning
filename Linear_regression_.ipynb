# %% [markdown]
# # **Python for Machine Learning**

# %% [markdown]
# **Linear Regression**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

x=np.array([1,5,13,25,33,46]).reshape((-1,1))
y=np.array([3,6,15,12,21,18])

plt.scatter(x,y)
plt.xlabel("IV")
plt.ylabel("DV")
plt.show()

from sklearn.linear_model import LinearRegression
SLR=LinearRegression()
SLR.fit(x,y)
pred=SLR.predict(x)

from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y,pred)
plt.plot(x,pred,color='Red',marker='*')
print("MSE=",mse)
print("intercept=",SLR.intercept_)
print("slope=",SLR.coef_)
# Out:
# MSE= 11.247422680412372
# intercept= 5.525773195876288
# slope= [0.34020619]

# %% [markdown]
# **X and Y values from a random funtion**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
x = []
y=[]
for i in range(6):
  random_num = random.randint(1, 100)
  x.append(random_num)
for j in range(6):
  random_num = random.randint(1, 100)
  y.append(random_num)
print(x)
print(y)
x=np.array(x).reshape(-1, 1)
y=np.array(y)
plt.scatter(x,y,color='green',marker='*')
plt.show()
from sklearn.linear_model import LinearRegression
SLR=LinearRegression()
SLR.fit(x,y)
pred=SLR.predict(x)
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y,pred)
plt.plot(x,pred,color='red',marker='*')
print("MSE:",mse)
print("intercept: ",SLR.intercept_)
print("slope: ",SLR.coef_)
# Out:
# [100, 63, 98, 48, 28, 84]
# [4, 95, 28, 62, 53, 28]
# MSE: 491.9179601771677
# intercept:  95.46422728542356
# slope:  [-0.71920514]

# %% [markdown]
# **X and Y values from excel sheet**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data=pd.read_csv('/content/drive/MyDrive/5_6298422814911237036.csv')
x=data.loc[:,'x'].values
y=data.loc[:,'y'].values
print(x)
print(y)
x=np.array(x).reshape(-1, 1)
y=np.array(y)
plt.scatter(x,y,color='green',marker='*')
plt.show()
from sklearn.linear_model import LinearRegression
SLR=LinearRegression()
SLR.fit(x,y)
pred=SLR.predict(x)
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y,pred)
plt.plot(x,pred,color='red',marker='*')
print("MSE:",mse)
print("intercept: ",SLR.intercept_)
print("slope: ",SLR.coef_)
# Out:
# [ 77  21  22  20  36  15  62  95  20   5   4  19  96  62  36  15  65  14
#   87  69  89  51  89  27  97  58  79  21  93  27  99  31  33  80  28  47
#   53  69  28  33  91  71  50  76   4  37  70  68  40  35  94  88  52  31
#   59   0  39  64  69  57  13  72  76  61  82  18  41  50  55  13  46  13
#   79  53  15  28  81  69  52  84  68  27  56  48  40  39  82 100  59  43
#   67  38  63  91  60  14  21  87  73  32   2  82  19  74  42  12   1  90
#   89   0  41  16  94  97  66  24  17  90  13   0  64  96  98  12  41  47
#   78  20  89  29  64  75  12  25  28  30  65  59  64  53  71  97  73   9
#   12  63  99  60  35   2  60  32  94  84  63  22  81  93  33   7  42  46
#   54  16  49  43  95  66  21  35  80  37  54  56   1  32  58  32  46  72
#   17  97  93  91  37   4  54  51  27  46  92  73  77  91  61  99   4  72
#   19  57  78  26  74  90  66  13  40  77  67  75  23  45  59  44  23  55
#   55  95  12   4   7 100  48  42  96  39 100  87  14  14  37   5  88  91
# ...
